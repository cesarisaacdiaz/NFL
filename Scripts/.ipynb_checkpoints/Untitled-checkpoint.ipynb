# %%
import os
import pandas as pd
import numpy as np

# %%
input_file_draft = os.path.join("..","..","Resources","draft.csv")

output_file_dolphins = os.path.join("..","Clean_Data","dolphins.csv")

# %%
draft_df = pd.read_csv(input_file_draft)
dolphins = draft_df[['playerId','draft','teamId','draftTeam','nameFull','position']]
dolphins
# Out:
#        playerId  draft  teamId draftTeam          nameFull position
# 0      19770001   1977    4900        TB        Ricky Bell       RB
# 1      19770002   1977    1200       DAL      Tony Dorsett       RB
# 2      19770003   1977     920       CIN     Eddie Edwards       DE
# 3      19770004   1977    3430       NYJ     Marvin Powell       OT
# 4      19770005   1977    3410       NYG        Gary Jeter       DE
# ...         ...    ...     ...       ...               ...      ...
# 12135  20190250   2019    3000       MIN    Austin Cutting       LS
# 12136  20190251   2019    2520       LAR      Dakota Allen       LB
# 12137  20190252   2019    3200        NE       Ken Webster       CB
# 12138  20190253   2019    5110       WAS  Jordan Brailford       DE
# 12139  20190254   2019    3800       ARI      Caleb Wilson       TE
#
# [12140 rows x 6 columns]

# %%
dolphins=dolphins[dolphins['draft']>=2014]
dolphins=dolphins[dolphins['draftTeam']=='MIA']
dolphins
# Out:
#        playerId  draft  teamId draftTeam            nameFull position
# 10623  20140019   2014    2700       MIA       Ja'Wuan James       OT
# 10667  20140063   2014    2700       MIA       Jarvis Landry       WR
# 10671  20140067   2014    2700       MIA        Billy Turner       OT
# 10729  20140125   2014    2700       MIA         Walt Aikens       CB
# 10759  20140155   2014    2700       MIA        Arthur Lynch       TE
# 10775  20140171   2014    2700       MIA        Jordan Tripp      OLB
# 10794  20140190   2014    2700       MIA          Matt Hazel       WR
# 10838  20140234   2014    2700       MIA       Terrence Fede       DE
# 10874  20150014   2015    2700       MIA      DeVante Parker       WR
# 10912  20150052   2015    2700       MIA     Jordan Phillips       DT
# 10974  20150114   2015    2700       MIA       Jamil Douglas       OL
# 11005  20150145   2015    2700       MIA        Bobby McCain       CB
# ...

# %%
dolphins.to_csv(output_file_dolphins,index=False,header=True)
