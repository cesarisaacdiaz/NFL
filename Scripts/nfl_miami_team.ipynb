# %% [markdown]
# Espacio para Importar las dependencias o librerias

# %%
import os
import pandas as pd
import numpy as np

# %%
input_file = os.path.join("..","Resources")
draft_file = 'draft.csv'
players_file = 'players.csv'
game_participation_file = 'gameParticipation.csv'
games_file = 'games.csv'

fumble_file = 'fumbles.csv'
interceptions_file = 'interceptions.csv'
sacks_file = 'sacks.csv'

output_file = os.path.join('..','Output','total_players.csv')

# %%
draft_df = pd.read_csv(input_file +'/'+ draft_file)
draft_df.head()

#draft_df = draft_df.loc[draft_df['teamId']==2700]
team_df = draft_df[['teamId','draftTeam']]
team_df = team_df.drop_duplicates()
team_df
# Out:
#        teamId draftTeam
# 0        4900        TB
# 1        1200       DAL
# 2         920       CIN
# 3        3430       NYJ
# 4        3410       NYG
# 5         200       ATL
# 6        3300        NO
# 8        1800        GB
# 9        2310        KC
# 10       2100        HO
# 11        610       BUF
# 12       2700       MIA
# 13       4600       SEA
# 14        810       CHI
# 15       3200        NE
# 16       1050       CLV
# 17       1400       DEN
# 18       2510        SL
# 20       3900       PIT
# 22       2510        LA
# 23       4400        SD
# 25        325       BLT
# 26       3000       MIN
# 34       2520       OAK
# 41       1540       DET
# 64       4500        SF
# 96       5110       WAS
# 118      3700       PHI
# 1673     2520       LAR
# 2340     2200       IND
# 3683     3800       ARZ
# 5788     2250       JAX
# 5791      750       CAR
# 6307     2100       TEN
# 7524     2120       HST
# 11376    4400       LAC
# 11879    3800       ARI
# 11901    2100       HOU
# 11903     325       BAL
# 11924    1050       CLE

# %%
players_df = pd.read_csv(input_file + '/' + players_file)
players_df.head()

players_df = players_df[['playerId','nameFull','position']]
players_df.head()
# Out:
#    playerId       nameFull position
# 0  19770001     Ricky Bell       RB
# 1  19770002   Tony Dorsett       RB
# 2  19770003  Eddie Edwards       DE
# 3  19770004  Marvin Powell       OT
# 4  19770005     Gary Jeter       DE

# %%
participation_df = pd.read_csv(input_file + '/'+ game_participation_file)
participation_df.head()

participation_df = participation_df[['gameId','teamId','playerId','nameFull','position','gamePartUnit']]
#participation_df['gamePartUnit'].value_counts()
#miami_team_df = participation_df.loc[participation_df['teamId']==2700]
defenders_team_df = participation_df.loc[participation_df['gamePartUnit']=='defense']
defenders_team_df.head()
# Out:
#        gameId  teamId  playerId         nameFull position gamePartUnit
# 13973   56473    3800  20140027   Deone Bucannon        S      defense
# 13974   56473    3800  20140160       Ed Stinson       DE      defense
# 13975   56473    3800  20130757   Tony Jefferson        S      defense
# 13976   56473    3800  20090095   Rashad Johnson        S      defense
# 13977   56473    3800  20080050  Calais Campbell       DE      defense

# %%
defenders_team_df = pd.merge(defenders_team_df,team_df,how='inner',on='teamId')
defenders_team_df
# Out:
#         gameId  teamId  playerId        nameFull position gamePartUnit  \
# 0        56473    3800  20140027  Deone Bucannon        S      defense
# 1        56473    3800  20140027  Deone Bucannon        S      defense
# 2        56473    3800  20140160      Ed Stinson       DE      defense
# 3        56473    3800  20140160      Ed Stinson       DE      defense
# 4        56473    3800  20130757  Tony Jefferson        S      defense
# ...        ...     ...       ...             ...      ...          ...
# 140706   58153    2520  20130832   Benson Mayowa       DE      defense
# 140707   58153    2520  20140133    Nevin Lawson       DB      defense
# 140708   58153    2520  20140133    Nevin Lawson       DB      defense
# 140709   58153    2520  20180837  Dallin Leavitt       DB      defense
# 140710   58153    2520  20180837  Dallin Leavitt       DB      defense
#
#        draftTeam
# 0            ARZ
# 1            ARI
# 2            ARZ
# 3            ARI
# 4            ARZ
# ...          ...
# 140706       LAR
# 140707       OAK
# 140708       LAR
# 140709       OAK
# 140710       LAR
#
# [140711 rows x 7 columns]

# %%
games_df = pd.read_csv(input_file + '/'+ games_file)
games_df.head()

games_df = games_df[['gameId','season','week','gameDate','homeTeamId','visitorTeamId','seasonType','winningTeam']]
games_df = games_df.loc[games_df['season']>=2014]
#season_2019 = season_2019.loc[season_2019['seasonType']!='PRE']
#season_2019 = season_2019[(season_2019['homeTeamId']==2700)|(season_2019['homeTeamId']==2700)]
games_df.head()
# Out:
#       gameId  season  week    gameDate  homeTeamId  visitorTeamId seasonType  \
# 1991   56426    2014     0  2014-08-03         610           3410        PRE
# 1992   56429    2014     1  2014-08-07        5110           3200        PRE
# 1993   56428    2014     1  2014-08-07         325           4500        PRE
# 1994   56427    2014     1  2014-08-07        3430           2200        PRE
# 1995   56432    2014     1  2014-08-07        4400           1200        PRE
#
#       winningTeam
# 1991         3410
# 1992         5110
# 1993          325
# 1994         3430
# 1995         4400

# %%
players_final_df = pd.merge(games_df,defenders_team_df,how='left',on='gameId')
players_final_df.head()

players_final_df = players_final_df[['playerId','nameFull','position','draftTeam']]
players_final_df = players_final_df.drop_duplicates()
players_final_df
# Out:
#           playerId         nameFull position draftTeam
# 0       20130105.0    Duke Williams        S       BUF
# 1       20140073.0    Preston Brown       LB       BUF
# 2       20110847.0    Corbin Bryant       DE       BUF
# 3       20110818.0     Mario Butler       DB       BUF
# 4       20090182.0      Jarius Wynn       DE       BUF
# ...            ...              ...      ...       ...
# 139550  20130054.0     Jamar Taylor       DB       ATL
# 139870  20130057.0  D.J. Swearinger        S        NO
# 139898  20170118.0     Mack Hollins       WR       MIA
# 140080  20170172.0  Isaiah McKenzie       WR       BUF
# 140178  20140444.0      Jamie Meder       DT       DET
#
# [4848 rows x 4 columns]

# %%
players_final_df
players_group = players_final_df.groupby(by='playerId')
games_played = pd.DataFrame(players_group['gameId'].count())
games_played = games_played.reset_index()
games_played
# Out:
#         playerId  gameId
# 0     19980004.0     114
# 1     19990007.0       6
# 2     20000013.0      18
# 3     20010004.0      51
# 4     20010029.0      39
# ...          ...     ...
# 2801  20191189.0       6
# 2802  20191190.0       2
# 2803  20191195.0       6
# 2804  20191198.0       2
# 2805  20191199.0       2
#
# [2806 rows x 2 columns]

# %%
players_final_df = pd.merge(players_final_df,games_played,how='left',on='playerId')
players_final_df
# Out:
#         playerId         nameFull position draftTeam  gameId
# 0     20130105.0    Duke Williams        S       BUF    63.0
# 1     20140073.0    Preston Brown       LB       BUF   156.0
# 2     20110847.0    Corbin Bryant       DE       BUF    64.0
# 3     20110818.0     Mario Butler       DB       BUF     9.0
# 4     20090182.0      Jarius Wynn       DE       BUF    48.0
# ...          ...              ...      ...       ...     ...
# 4843  20130054.0     Jamar Taylor       DB       ATL   190.0
# 4844  20130057.0  D.J. Swearinger        S        NO   164.0
# 4845  20170118.0     Mack Hollins       WR       MIA     2.0
# 4846  20170172.0  Isaiah McKenzie       WR       BUF     2.0
# 4847  20140444.0      Jamie Meder       DT       DET   114.0
#
# [4848 rows x 5 columns]

# %%
fumble_df = pd.read_csv(input_file +'/'+ fumble_file)
fumble_df = fumble_df[['playerId','playId','gameId']]
fumble_df.head()

fumble_group = fumble_df.groupby(by='playerId')
count_fumbled = pd.DataFrame(fumble_group['playerId'].count())
count_fumbled = count_fumbled.rename(columns = {'playerId':'fumbles'})
count_fumbled = count_fumbled.reset_index()
count_fumbled
# Out:
#      playerId  fumbles
# 0    19960026        1
# 1    19970066        1
# 2    19980004        6
# 3    19980012        1
# 4    19980013        1
# ..        ...      ...
# 892  20190161        2
# 893  20190173        1
# 894  20190190        1
# 895  20190196        1
# 896  20190201        1
#
# [897 rows x 2 columns]

# %%
players_final_df = pd.merge(players_final_df,count_fumbled,how='left',on='playerId')
players_final_df
# Out:
#         playerId         nameFull position draftTeam  gameId  fumbles
# 0     20130105.0    Duke Williams        S       BUF    63.0      1.0
# 1     20140073.0    Preston Brown       LB       BUF   156.0      3.0
# 2     20110847.0    Corbin Bryant       DE       BUF    64.0      NaN
# 3     20110818.0     Mario Butler       DB       BUF     9.0      NaN
# 4     20090182.0      Jarius Wynn       DE       BUF    48.0      NaN
# ...          ...              ...      ...       ...     ...      ...
# 4843  20130054.0     Jamar Taylor       DB       ATL   190.0      2.0
# 4844  20130057.0  D.J. Swearinger        S        NO   164.0      9.0
# 4845  20170118.0     Mack Hollins       WR       MIA     2.0      NaN
# 4846  20170172.0  Isaiah McKenzie       WR       BUF     2.0      NaN
# 4847  20140444.0      Jamie Meder       DT       DET   114.0      NaN
#
# [4848 rows x 6 columns]

# %%
interceptions_df = pd.read_csv(input_file +'/'+ interceptions_file)

interceptions_df = interceptions_df[['playerId','playId','gameId']]
interceptions_df.head()

interceptions_group = interceptions_df.groupby(by='playerId')
count_interceptions = pd.DataFrame(interceptions_group['playerId'].count())
count_interceptions = count_interceptions.rename(columns = {'playerId':'interceptions'})
count_interceptions = count_interceptions.reset_index()
count_interceptions
# Out:
#      playerId  interceptions
# 0    19980004              4
# 1    20020002              2
# 2    20020128              1
# 3    20020242              1
# 4    20030005              2
# ..        ...            ...
# 394  20190143              2
# 395  20190146              2
# 396  20190148              1
# 397  20190155              1
# 398  20190201              1
#
# [399 rows x 2 columns]

# %%
players_final_df = pd.merge(players_final_df,count_interceptions,how='left',on='playerId')
players_final_df
# Out:
#         playerId         nameFull position draftTeam  gameId  fumbles  \
# 0     20130105.0    Duke Williams        S       BUF    63.0      1.0
# 1     20140073.0    Preston Brown       LB       BUF   156.0      3.0
# 2     20110847.0    Corbin Bryant       DE       BUF    64.0      NaN
# 3     20110818.0     Mario Butler       DB       BUF     9.0      NaN
# 4     20090182.0      Jarius Wynn       DE       BUF    48.0      NaN
# ...          ...              ...      ...       ...     ...      ...
# 4843  20130054.0     Jamar Taylor       DB       ATL   190.0      2.0
# 4844  20130057.0  D.J. Swearinger        S        NO   164.0      9.0
# 4845  20170118.0     Mack Hollins       WR       MIA     2.0      NaN
# 4846  20170172.0  Isaiah McKenzie       WR       BUF     2.0      NaN
# 4847  20140444.0      Jamie Meder       DT       DET   114.0      NaN
#
#       interceptions
# 0               1.0
# 1               1.0
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 4843            NaN
# 4844            6.0
# 4845            NaN
# 4846            NaN
# 4847            NaN
#
# [4848 rows x 7 columns]

# %%
sacks_df = pd.read_csv(input_file +'/'+ sacks_file)

sacks_df = sacks_df[['playerId','playId','gameId']]
sacks_df.head()

sacks_group = sacks_df.groupby(by='playerId')
count_sacks = pd.DataFrame(sacks_group['playerId'].count())
count_sacks = count_sacks.rename(columns = {'playerId':'sacks'})
count_sacks = count_sacks.reset_index()
count_sacks
# Out:
#      playerId  sacks
# 0    19980004      1
# 1    20010004      5
# 2    20020002     17
# 3    20020011      6
# 4    20020128      2
# ..        ...    ...
# 628  20190161      3
# 629  20190173      1
# 630  20190190      1
# 631  20190201      1
# 632  20190225      1
#
# [633 rows x 2 columns]

# %%
players_final_df = pd.merge(players_final_df,count_sacks,how='left',on='playerId')
players_final_df
# Out:
#         playerId         nameFull position draftTeam  gameId  fumbles  \
# 0     20130105.0    Duke Williams        S       BUF    63.0      1.0
# 1     20140073.0    Preston Brown       LB       BUF   156.0      3.0
# 2     20110847.0    Corbin Bryant       DE       BUF    64.0      NaN
# 3     20110818.0     Mario Butler       DB       BUF     9.0      NaN
# 4     20090182.0      Jarius Wynn       DE       BUF    48.0      NaN
# ...          ...              ...      ...       ...     ...      ...
# 4843  20130054.0     Jamar Taylor       DB       ATL   190.0      2.0
# 4844  20130057.0  D.J. Swearinger        S        NO   164.0      9.0
# 4845  20170118.0     Mack Hollins       WR       MIA     2.0      NaN
# 4846  20170172.0  Isaiah McKenzie       WR       BUF     2.0      NaN
# 4847  20140444.0      Jamie Meder       DT       DET   114.0      NaN
#
#       interceptions  sacks
# 0               1.0    NaN
# 1               1.0    NaN
# 2               NaN    NaN
# 3               NaN    NaN
# 4               NaN    2.0
# ...             ...    ...
# 4843            NaN    1.0
# 4844            6.0    2.0
# 4845            NaN    NaN
# 4846            NaN    NaN
# 4847            NaN    NaN
#
# [4848 rows x 8 columns]

# %%
players_final_df.to_csv(output_file,index=False,header=True)
